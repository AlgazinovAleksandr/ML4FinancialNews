# %%
import requests
import pandas as pd
from datetime import datetime, timedelta

# %%
# 1. Request with a browser-like User-Agent
url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) Chrome/129.0.0.0 Safari/537.36"
}

response = requests.get(url, headers=headers)
response.raise_for_status()  # check for errors

# 2. Parse HTML into pandas
tables = pd.read_html(response.text)
df_sp500 = tables[0]  # first table has the constituent list
df_sp500.sample(20)
# Out:
#     Symbol                       Security             GICS Sector  \
# 7      AES                AES Corporation               Utilities
# 25     AEP        American Electric Power               Utilities
# 222   GDDY                        GoDaddy  Information Technology
# 97     CRL     Charles River Laboratories             Health Care
# 469   VRSN                       Verisign  Information Technology
# 334    NEE                 NextEra Energy               Utilities
# 361   PAYX                        Paychex             Industrials
# 108      C                      Citigroup              Financials
# 455    TSN                    Tyson Foods        Consumer Staples
# 319    TAP  Molson Coors Beverage Company        Consumer Staples
# 487    WFC                    Wells Fargo              Financials
# 10     APD                   Air Products               Materials
# 100    CVX            Chevron Corporation                  Energy
# 489    WST   West Pharmaceutical Services             Health Care
# 41    APTV                          Aptiv  Consumer Discretionary
# 28     AMT                 American Tower             Real Estate
# 248   INCY                         Incyte             Health Care
# 148   DXCM                         Dexcom             Health Care
# 409    STX             Seagate Technology  Information Technology
# 60     BDX               Becton Dickinson             Health Care
#
#                                 GICS Sub-Industry  \
# 7    Independent Power Producers & Energy Traders
# 25                             Electric Utilities
# 222            Internet Services & Infrastructure
# 97                 Life Sciences Tools & Services
# 469            Internet Services & Infrastructure
# 334                               Multi-Utilities
# 361          Human Resource & Employment Services
# 108                             Diversified Banks
# 455                        Packaged Foods & Meats
# 319                                       Brewers
# 487                             Diversified Banks
# 10                               Industrial Gases
# 100                          Integrated Oil & Gas
# 489                          Health Care Supplies
# 41                   Automotive Parts & Equipment
# 28                            Telecom Tower REITs
# 248                                 Biotechnology
# 148                         Health Care Equipment
# 409    Technology Hardware, Storage & Peripherals
# 60                          Health Care Equipment
#
#                      Headquarters Location  Date added      CIK  \
# 7                      Arlington, Virginia  1998-10-02   874761
# 25                          Columbus, Ohio  1957-03-04     4904
# 222                         Tempe, Arizona  2024-06-24  1609711
# 97               Wilmington, Massachusetts  2021-05-14  1100682
# 469                       Reston, Virginia  2006-02-01  1014473
# 334                    Juno Beach, Florida  1976-06-30   753308
# 361                     Penfield, New York  1998-10-01   723531
# 108                New York City, New York  1988-05-31   831001
# 455                   Springdale, Arkansas  2005-08-10   100493
# 319                      Chicago, Illinois  1976-06-30    24545
# 487              San Francisco, California  1976-06-30    72971
# 10   Upper Macungie Township, Pennsylvania  1985-04-30     2969
# 100                         Houston, Texas  1957-03-04    93410
# 489                    Exton, Pennsylvania  2020-05-22   105770
# 41                         Dublin, Ireland  2012-12-24  1521332
# 28                   Boston, Massachusetts  2007-11-19  1053507
# 248                   Wilmington, Delaware  2017-02-28   879169
# 148                  San Diego, California  2020-05-12  1093557
# 409                        Dublin, Ireland  2012-07-02  1137789
# 60              Franklin Lakes, New Jersey  1972-09-30    10795
#
#                             Founded
# 7                              1981
# 25                             1906
# 222                            1997
# 97                             1947
# 469                            1995
# 334                     1984 (1925)
# 361                            1971
# 108                            1998
# 455                            1935
# 319  2005 (Molson 1786, Coors 1873)
# 487                            1852
# 10                             1940
# 100                            1879
# 489                            1923
# 41                             1994
# 28                             1995
# 248                            1991
# 148                            1999
# 409                            1979
# 60                             1897

# %%
tickers = df_sp500["Symbol"].tolist()
print(f"Fetched {len(tickers)} tickers!")
tickers[:25]
# Out:
# Fetched 503 tickers!
# ['MMM',
#  'AOS',
#  'ABT',
#  'ABBV',
#  'ACN',
#  'ADBE',
#  'AMD',
#  'AES',
#  'AFL',
#  'A',
#  'APD',
#  'ABNB',
#  'AKAM',
#  'ALB',
#  'ARE',
#  'ALGN',
#  'ALLE',
#  'LNT',
#  'ALL',
#  'GOOGL',
#  'GOOG',
#  'MO',
#  'AMZN',
#  'AMCR',
#  'AEE']

# %%
import pandas_datareader.data as web
from datetime import datetime

# Stooq requires '.US' suffix for American stocks
tickers = [ticker.replace('.', '-') + '.US' for ticker in tickers]
start = datetime(2020, 1, 1)
end = datetime.now()

# %%
tickers[:25]
# Out:
# ['MMM.US',
#  'AOS.US',
#  'ABT.US',
#  'ABBV.US',
#  'ACN.US',
#  'ADBE.US',
#  'AMD.US',
#  'AES.US',
#  'AFL.US',
#  'A.US',
#  'APD.US',
#  'ABNB.US',
#  'AKAM.US',
#  'ALB.US',
#  'ARE.US',
#  'ALGN.US',
#  'ALLE.US',
#  'LNT.US',
#  'ALL.US',
#  'GOOGL.US',
#  'GOOG.US',
#  'MO.US',
#  'AMZN.US',
#  'AMCR.US',
#  'AEE.US']

# %%
dfs = []
failed_tickers = []

print("Downloading from Stooq...\n")

for ticker in tickers:
    try:
        df = web.DataReader(ticker, "stooq", start, end)

        # Stooq returns newest → oldest
        df = df.sort_index()

        # Add ticker column
        df["ticker"] = ticker

        dfs.append(df)
        print(f"✅ Success: {ticker}")

    except Exception as e:
        failed_tickers.append(ticker)
        print(f"❌ Failed: {ticker} | {type(e).__name__}")

# Concatenate by rows
if dfs:
    final_df = pd.concat(dfs, axis=0)
else:
    final_df = pd.DataFrame()
# Out:
# Downloading from Stooq...
#
# ✅ Success: MMM.US
# ✅ Success: AOS.US
# ✅ Success: ABT.US
# ✅ Success: ABBV.US
# ✅ Success: ACN.US
# ✅ Success: ADBE.US
# ✅ Success: AMD.US
# ✅ Success: AES.US
# ✅ Success: AFL.US
# ✅ Success: A.US
# ✅ Success: APD.US
# ❌ Failed: ABNB.US | ReadTimeout
# ✅ Success: AKAM.US
# ✅ Success: ALB.US
# ✅ Success: ARE.US
# ✅ Success: ALGN.US
# ✅ Success: ALLE.US
# ✅ Success: LNT.US
# ✅ Success: ALL.US
# ✅ Success: GOOGL.US
# ✅ Success: GOOG.US
# ❌ Failed: MO.US | ReadTimeout
# ✅ Success: AMZN.US
# ✅ Success: AMCR.US
# ✅ Success: AEE.US
# ✅ Success: AEP.US
# ✅ Success: AXP.US
# ✅ Success: AIG.US
# ✅ Success: AMT.US
# ✅ Success: AWK.US
# ✅ Success: AMP.US
# ✅ Success: AME.US
# ✅ Success: AMGN.US
# ✅ Success: APH.US
# ✅ Success: ADI.US
# ✅ Success: AON.US
# ✅ Success: APA.US
# ✅ Success: APO.US
# ✅ Success: AAPL.US
# ✅ Success: ITW.US
# ✅ Success: INCY.US
# ✅ Success: IR.US
# ✅ Success: PODD.US
# ✅ Success: INTC.US
# ✅ Success: IBKR.US
# ✅ Success: ICE.US
# ✅ Success: IFF.US
# ✅ Success: IP.US
# ✅ Success: INTU.US
# ✅ Success: ISRG.US
# ✅ Success: IVZ.US
# ✅ Success: INVH.US
# ✅ Success: IQV.US
# ✅ Success: IRM.US
# ✅ Success: JBHT.US
# ✅ Success: JBL.US
# ✅ Success: JKHY.US
# ✅ Success: J.US
# ✅ Success: JNJ.US
# ✅ Success: JCI.US
# ✅ Success: JPM.US
# ✅ Success: KVUE.US
# ✅ Success: KDP.US
# ✅ Success: KEY.US
# ✅ Success: KEYS.US
# ✅ Success: KMB.US
# ✅ Success: KIM.US
# ✅ Success: KMI.US
# ✅ Success: KKR.US
# ✅ Success: KLAC.US
# ✅ Success: KHC.US
# ✅ Success: KR.US
# ✅ Success: LHX.US
# ✅ Success: LH.US
# ✅ Success: LRCX.US
# ✅ Success: LW.US
# ✅ Success: LVS.US
# ✅ Success: LDOS.US
# ✅ Success: LEN.US
# ✅ Success: LII.US
# ✅ Success: LLY.US
# ✅ Success: LIN.US
# ✅ Success: LYV.US
# ✅ Success: LMT.US
# ✅ Success: L.US
# ✅ Success: LOW.US
# ✅ Success: LULU.US
# ✅ Success: LYB.US
# ✅ Success: MTB.US
# ✅ Success: MPC.US
# ✅ Success: MAR.US
# ✅ Success: MRSH.US
# ✅ Success: MLM.US
# ✅ Success: MAS.US
# ✅ Success: MA.US
# ✅ Success: MTCH.US
# ✅ Success: MKC.US
# ✅ Success: MCD.US
# ✅ Success: MCK.US
# ✅ Success: MDT.US
# ✅ Success: MRK.US
# ✅ Success: META.US
# ✅ Success: MET.US
# ✅ Success: MTD.US
# ✅ Success: MGM.US
# ✅ Success: MCHP.US
# ✅ Success: MU.US
# ✅ Success: MSFT.US
# ✅ Success: MAA.US
# ✅ Success: MRNA.US
# ✅ Success: MOH.US
# ✅ Success: TAP.US
# ✅ Success: MDLZ.US
# ✅ Success: MPWR.US
# ✅ Success: MNST.US
# ✅ Success: MCO.US
# ✅ Success: MS.US
# ✅ Success: MOS.US
# ✅ Success: MSI.US
# ✅ Success: MSCI.US
# ✅ Success: NDAQ.US
# ✅ Success: NTAP.US
# ✅ Success: NFLX.US
# ✅ Success: NEM.US
# ✅ Success: NWSA.US
# ✅ Success: NWS.US
# ✅ Success: NEE.US
# ✅ Success: NKE.US
# ✅ Success: NI.US
# ✅ Success: NDSN.US
# ✅ Success: NSC.US
# ✅ Success: NTRS.US
# ✅ Success: NOC.US
# ✅ Success: NCLH.US
# ✅ Success: NRG.US
# ✅ Success: NUE.US
# ✅ Success: NVDA.US
# ✅ Success: NVR.US
# ✅ Success: NXPI.US
# ✅ Success: ORLY.US
# ✅ Success: OXY.US
# ✅ Success: ODFL.US
# ✅ Success: OMC.US
# ❌ Failed: ON.US | ReadTimeout
# ✅ Success: OKE.US
# ✅ Success: ORCL.US
# ✅ Success: OTIS.US
# ✅ Success: PCAR.US
# ✅ Success: PKG.US
# ✅ Success: PLTR.US
# ✅ Success: PANW.US
# ✅ Success: PSKY.US
# ✅ Success: PH.US
# ✅ Success: PAYX.US
# ✅ Success: PAYC.US
# ✅ Success: PYPL.US
# ✅ Success: PNR.US
# ✅ Success: PEP.US
# ✅ Success: PFE.US
# ✅ Success: PCG.US
# ✅ Success: PM.US
# ✅ Success: PSX.US
# ✅ Success: PNW.US
# ✅ Success: PNC.US
# ✅ Success: POOL.US
# ✅ Success: PPG.US
# ✅ Success: PPL.US
# ✅ Success: PFG.US
# ✅ Success: PG.US
# ✅ Success: PGR.US
# ✅ Success: PLD.US
# ✅ Success: PRU.US
# ✅ Success: PEG.US
# ✅ Success: PTC.US
# ✅ Success: PSA.US
# ✅ Success: PHM.US
# ✅ Success: PWR.US
# ✅ Success: QCOM.US
# ✅ Success: DGX.US
# ✅ Success: Q.US
# ✅ Success: RL.US
# ✅ Success: RJF.US
# ✅ Success: RTX.US
# ✅ Success: O.US
# ✅ Success: REG.US
# ✅ Success: REGN.US
# ✅ Success: RF.US
# ✅ Success: RSG.US
# ✅ Success: RMD.US
# ✅ Success: RVTY.US
# ✅ Success: HOOD.US
# ✅ Success: ROK.US
# ✅ Success: ROL.US
# ✅ Success: ROP.US
# ✅ Success: ROST.US
# ✅ Success: RCL.US
# ✅ Success: SPGI.US
# ✅ Success: CRM.US
# ✅ Success: SNDK.US
# ✅ Success: SBAC.US
# ✅ Success: SLB.US
# ✅ Success: STX.US
# ✅ Success: SRE.US
# ✅ Success: NOW.US
# ✅ Success: SHW.US
# ✅ Success: SPG.US
# ✅ Success: SWKS.US
# ✅ Success: SJM.US
# ✅ Success: SW.US
# ✅ Success: SNA.US
# ✅ Success: SOLV.US
# ✅ Success: SO.US
# ✅ Success: LUV.US
# ✅ Success: SWK.US
# ✅ Success: SBUX.US
# ✅ Success: STT.US
# ✅ Success: STLD.US
# ✅ Success: STE.US
# ✅ Success: SYK.US
# ✅ Success: SMCI.US
# ✅ Success: SYF.US
# ✅ Success: SNPS.US
# ✅ Success: SYY.US
# ✅ Success: TMUS.US
# ✅ Success: TROW.US
# ✅ Success: TTWO.US
# ✅ Success: TPR.US
# ✅ Success: TRGP.US
# ✅ Success: TGT.US
# ✅ Success: TEL.US
# ✅ Success: TDY.US
# ✅ Success: TER.US
# ✅ Success: TSLA.US
# ✅ Success: TXN.US
# ✅ Success: TPL.US
# ✅ Success: TXT.US
# ❌ Failed: TMO.US | ReadTimeout
# ✅ Success: TJX.US
# ✅ Success: TKO.US
# ✅ Success: TTD.US
# ✅ Success: TSCO.US
# ✅ Success: TT.US
# ✅ Success: TDG.US
# ✅ Success: TRV.US
# ✅ Success: TRMB.US
# ✅ Success: TFC.US
# ✅ Success: TYL.US
# ✅ Success: TSN.US
# ✅ Success: USB.US
# ✅ Success: UBER.US
# ✅ Success: UDR.US
# ✅ Success: ULTA.US
# ✅ Success: UNP.US
# ✅ Success: UAL.US
# ✅ Success: UPS.US
# ✅ Success: URI.US
# ✅ Success: UNH.US
# ✅ Success: UHS.US
# ✅ Success: VLO.US
# ✅ Success: VTR.US
# ✅ Success: VLTO.US
# ✅ Success: VRSN.US
# ✅ Success: VRSK.US
# ✅ Success: VZ.US
# ✅ Success: VRTX.US
# ✅ Success: VTRS.US
# ✅ Success: VICI.US
# ✅ Success: V.US
# ❌ Failed: VST.US | ReadTimeout
# ✅ Success: VMC.US
# ✅ Success: WRB.US
# ✅ Success: GWW.US
# ✅ Success: WAB.US
# ✅ Success: WMT.US
# ✅ Success: DIS.US
# ✅ Success: WBD.US
# ✅ Success: WM.US
# ✅ Success: WAT.US
# ✅ Success: WEC.US
# ✅ Success: WFC.US
# ✅ Success: WELL.US
# ✅ Success: WST.US
# ✅ Success: WDC.US
# ✅ Success: WY.US
# ✅ Success: WSM.US
# ✅ Success: WMB.US
# ✅ Success: WTW.US
# ✅ Success: WDAY.US
# ✅ Success: WYNN.US
# ✅ Success: XEL.US
# ✅ Success: XYL.US
# ✅ Success: YUM.US
# ✅ Success: ZBRA.US
# ✅ Success: ZBH.US
# ✅ Success: ZTS.US

# %%
print("\nSummary")
print("--------")
print(f"Successful: {len(dfs)}")
print(f"Failed: {len(failed_tickers)}")

final_df
# Out:
# Summary
# --------
# Successful: 494
# Failed: 9
#             ticker      Open      High       Low     Close        Volume
# 2020-01-02  AES.US   18.3302   18.4467   18.2463   18.3835  3.254986e+06
# 2020-01-03  AES.US   18.2551   18.3933   18.1180   18.1732  5.828317e+06
# 2020-01-06  AES.US   18.1269   18.3933   18.1180   18.3835  4.741658e+06
# 2020-01-07  AES.US   18.3766   18.4664   18.2463   18.4467  3.530769e+06
# 2020-01-08  AES.US   18.4852   18.5859   18.2551   18.4131  4.877053e+06
# ...            ...       ...       ...       ...       ...           ...
# 2026-01-21  ZTS.US  123.6750  127.1200  123.6750  125.0800  5.201868e+06
# 2026-01-22  ZTS.US  124.2800  126.4700  123.7300  124.4000  4.715418e+06
# 2026-01-23  ZTS.US  124.3900  124.8100  123.5100  124.0500  3.339665e+06
# 2026-01-26  ZTS.US  123.9100  124.9800  122.9700  123.9200  4.262127e+06
# 2026-01-27  ZTS.US  123.8950  126.2900  123.0500  124.9600  3.587333e+06
#
# [24077 rows x 6 columns]

# %%
# TODO: fix why most tickers are not here!
final_df.ticker.value_counts()
# Out:
# AES.US     1525
# ALLE.US    1525
# GOOG.US    1525
# T.US       1525
# BSX.US     1525
# BXP.US     1525
# CVNA.US    1525
# KMB.US     1525
# POOL.US    1525
# PFG.US     1525
# STX.US     1525
# TJX.US     1525
# GWW.US     1525
# WAT.US     1525
# ZTS.US     1525
# APP.US     1202
# Name: ticker, dtype: int64
