# %% [markdown]
# TODO:
#
# + make it normal eda
#
# + rename to eda.ipynb
#
# + push

# %%
import pandas as pd

# %%
df = pd.read_csv('data_sample/news_prices_full.csv')
df.head()
# Out:
#           date_publish              date_download      source_domain  \
# 0  2019-08-03 00:00:00  2019-09-03 17:40:27+00:00  finance.yahoo.com
# 1  2019-08-03 00:00:00  2019-09-03 17:40:27+00:00  finance.yahoo.com
# 2  2019-01-22 07:29:49  2019-01-22 08:20:01+00:00  finance.yahoo.com
# 3  2019-08-01 13:03:23  2019-08-01 13:23:12+00:00  finance.yahoo.com
# 4  2019-10-31 13:48:15  2019-10-31 14:39:52+00:00  finance.yahoo.com
#
#          news_outlet                                              title  \
# 0  finance.yahoo.com  Google’s new Android Focus Mode could break yo...
# 1  finance.yahoo.com  Google’s new Android Focus Mode could break yo...
# 2  finance.yahoo.com  UBS Warns on Client Activity After $13 Billion...
# 3  finance.yahoo.com     Shopify Boosts Outlook on New Online Offerings
# 4  finance.yahoo.com  Wayfair Plunges as Forecast Miss Heightens Gro...
#
#                                          description  \
# 0  Google's new Focus Mode feature for Android is...
# ...

# %% [markdown]
# **Check ticker distribution**

# %%
# top 20
df['ticker'].value_counts()[:20]
# Out:
# T        12372
# C        11973
# META      8075
# GOOGL     7389
# AAPL      7254
# AMZN      6232
# V         6040
# MSFT      4324
# TSLA      4232
# GS        3573
# JPM       2591
# MA        2281
# BA        1963
# MU        1574
# NFLX      1452
# NVDA      1408
# INTC      1375
# BRK       1281
# BAC       1268
# BABA      1198
# Name: ticker, dtype: int64

# %% [markdown]
# **Check nans**

# %%
df.isnull().sum()
# Out:
# date_publish               0
# date_download              0
# source_domain              0
# news_outlet                0
# title                      0
# description               35
# maintext                   0
# url                        0
# language                   0
# sentiment_negative         0
# sentiment_neutral          0
# sentiment_positive         0
# emotion_anger              0
# emotion_fear               0
# emotion_joy                0
# emotion_sadness            0
# emotion_disgust            0
# emotion_surprise           0
# emotion_neutral            0
# named_entities             0
# mentioned_companies        0
# related_companies          0
# industries                 0
# ticker                     0
# prev_day_price         14461
# curr_day_price         14451
# next_day_price         14461
# dtype: int64

# %% [markdown]
# ### Substitute nans with the real stock market data

# %% [markdown]
# ### Visualize the data
